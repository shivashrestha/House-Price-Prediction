# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/alaabakhti/miniconda3/envs/dsp/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/alaabakhti/miniconda3/envs/dsp/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alaabakhti/miniconda3/envs/dsp/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alaabakhti/miniconda3/envs/dsp/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alaabakhti/miniconda3/envs/dsp/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/alaabakhti/miniconda3/envs/dsp/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !ls ../../data
# Out:
# data_description.txt test.csv
# processed_df.parquet train.csv

# %%
import pandas as pd

DATA_FILENAME = '../../data/train.csv'

# %% [markdown]
# # Read data

# %% [markdown]
# - Read data

# %%
df_raw = pd.read_csv(DATA_FILENAME)

# %% [markdown]
# - Show head of data (first 5 rows)

# %%
df_raw.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df_raw.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [5 rows x 81 columns]

# %%
df_raw.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN    NaN        Shed     350
# 8         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
# 5     10   2009        WD         Normal     143000
# 6      8   2007        WD         Normal     307000
# 7     11   2009        WD         Normal     200000
# 8      4   2008        WD        Abnorml     129900
# 9      1   2008        WD         Normal     118000
#
# [10 rows x 81 columns]

# %% [markdown]
# - check how many rows you have in the data

# %%
df_raw.shape
# Out:
# (1460, 81)

# %% [markdown]
# - Filter data

# %%
label_col = 'SalePrice'
useful_features = ['Foundation', 'KitchenQual', 'TotRmsAbvGrd', 'WoodDeckSF', 'YrSold', '1stFlrSF']

# %%
df = df_raw[useful_features + [label_col]]
df.head()
# Out:
#   Foundation KitchenQual  TotRmsAbvGrd  WoodDeckSF  YrSold  1stFlrSF  \
# 0      PConc          Gd             8           0    2008       856
# 1     CBlock          TA             6         298    2007      1262
# 2      PConc          Gd             6           0    2008       920
# 3     BrkTil          Gd             7           0    2006       961
# 4      PConc          Gd             9         192    2008      1145
#
#    SalePrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000

# %%
df.shape
# Out:
# (1460, 7)

# %% [markdown]
# # Preprocess data

# %%
continuous_features = ['TotRmsAbvGrd', 'YrSold']
discrete_features = ['Foundation', 'KitchenQual']
features_to_one_hot_encode = ['Foundation']
features_to_oridinal_encode = ['KitchenQual']

# %% [markdown]
# - check the values and the count of a given feature

# %%
df['Foundation'].value_counts()
# Out:
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64

# %%
df['TotRmsAbvGrd'].value_counts()
# Out:
# TotRmsAbvGrd
# 6     402
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 2       1
# 14      1
# Name: count, dtype: int64

# %%
df['KitchenQual'].value_counts()
# Out:
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64

# %% [markdown]
# ## encoding

# %%
df_one_hot_code = pd.get_dummies(df[features_to_one_hot_encode])
df_one_hot_code.head()
# Out:
#    Foundation_BrkTil  Foundation_CBlock  Foundation_PConc  Foundation_Slab  \
# 0              False              False              True            False
# 1              False               True             False            False
# 2              False              False              True            False
# 3               True              False             False            False
# 4              False              False              True            False
#
#    Foundation_Stone  Foundation_Wood
# 0             False            False
# 1             False            False
# 2             False            False
# 3             False            False
# 4             False            False

# %% [markdown]
# ## TODO
# - categorize the rest of features
# - scale continuous features (df_scaled)
# - ordinal encode categorical features (quality, etc) (df_ordinal_encoded)
# - Concat the 3 dataframes in a single one (df_one_hot_code, df_ordinal_encoded, df_scaled)

# %%
df_final = df

# %% [markdown]
# # Training

# %% [markdown]
# - Create X and y

# %%
X, y = df_final.drop(columns=[label_col]), df_final[label_col]

# %% [markdown]
# - Split data in X_train, y_train, X_test, y_test https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# TODO

# %% [markdown]
# - Instantiate a LinearRegressor https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
# TODO

# %% [markdown]
# - Train the model (model.fit ...)

# %%
# TODO

# %% [markdown]
# # Evaluation

# %% [markdown]
# - make predictions (`y_pred = model.predict(X_test)`)

# %% [markdown]
# - compute performance using https://scikit-learn.org/stable/modules/generated/sklearn.metrics.root_mean_squared_error.html#sklearn.metrics.root_mean_squared_error
